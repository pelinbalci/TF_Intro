# %% [markdown]
# <a href="https://colab.research.google.com/github/pelinbalci/TF_Intro/blob/main/lecture_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# - Sequential of layers.
# - units = neurons
# - input_shape = the shape of the data. it is just one value.

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model = keras.Sequential(keras.layers.Dense(units=1, input_shape=[1]))
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xs, ys, epochs = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 464ms/step - loss: 98.5277
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 77.5256
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 61.0019
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 48.0017
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 37.7736
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 29.7265
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 23.3952
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 18.4139
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 14.4947
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 11.4111
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.9849
# Epoch 12/500
# 1/1 [==============================] - 0s 9ms/step - loss: 7.0760
# ...

# %%
model.predict([5])
# Out:
# array([[15.999038]], dtype=float32)
